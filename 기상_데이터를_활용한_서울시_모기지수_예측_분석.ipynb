# %% [markdown]
# # **기상 데이터를 활용한 서울시 모기지수 예측 분석**
# 20231439 정유정
# 20231459 황혜린
# 20231462 김수인

# %%
# 패키지 로딩
install.packages(c("dplyr", "caret", "readr"))
library(dplyr)
library(caret)
library(readr)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages(c("dplyr", "caret", "readr")):
# “installation of package ‘dplyr’ had non-zero exit status”
# Warning message in install.packages(c("dplyr", "caret", "readr")):
# “installation of package ‘caret’ had non-zero exit status”

# %%
# 데이터 불러오기
seoul_weather <- read.csv("서울시 자동기상 관측자료.csv", fileEncoding = "euc-kr")
seoul_mosquito <- read.csv("서울시 모기예보제 정보.csv", fileEncoding = "euc-kr")
seoul_mosquito <- seoul_mosquito[c(583:32),] # 날짜 범주 맞추기

# %%
# 결측치 처리 (강수량에만 결측치 존재, 비가 오지 않는 날이므로 0 대체)
seoul_weather[is.na(seoul_weather)] <- 0

# %%
# 데이터 병합
names(seoul_mosquito)[1] <- c("일시")
seoul_weather <- seoul_weather[,c(3:9)]
seoul_merge <- merge(seoul_mosquito, seoul_weather, by="일시")
seoul_merge
# Out:
#     일시       모기지수.수변부. 모기지수.주거지. 모기지수.공원. 평균기온..C.
# 1   2021.10.1  100.0            44.3             47.6           21.1
# 2   2021.10.10 100.0            41.2             45.0           19.9
# 3   2021.10.11 100.0            43.7             50.1           15.2
# 4   2021.10.12  94.8            40.1             38.4           17.9
# 5   2021.10.13  82.1            31.5             27.9           19.6
# 6   2021.10.14  99.8            36.7             40.0           19.7
# 7   2021.10.15  94.8            38.1             38.8           19.0
# 8   2021.10.16 100.0            39.9             52.0           10.7
# 9   2021.10.17 100.0            40.3             44.4            5.6
# 10  2021.10.18  35.4            16.1              0.4            9.6
# 11  2021.10.19  19.3             7.0              0.0           10.9
# 12  2021.10.2  100.0            39.7             45.1           20.7
# 13  2021.10.20  27.7            14.6              0.0            9.5
# 14  2021.10.21  51.5            20.2              8.6            9.8
# 15  2021.10.22  37.6            14.6              0.7           10.8
# 16  2021.10.23  39.3            15.1              2.0           11.4
# 17  2021.10.24  41.0            17.4              4.4           11.4
# 18  2021.10.25  43.8            18.1              5.5           11.7
# 19  2021.10.26  45.4            18.4              7.4           13.0
# 20  2021.10.27  47.1            20.0              7.1           13.4
# 21  2021.10.28  54.9            22.8             12.3           12.7
# 22  2021.10.29  66.5            25.1             19.1           14.6
# 23  2021.10.3  100.0            40.6             46.5           22.3
# 24  2021.10.30  51.5            20.7             10.8           13.8
# 25  2021.10.31  70.4            26.4             22.8           14.1
# 26  2021.10.4  100.0            40.2             44.3           22.9
# 27  2021.10.5  100.0            43.2             47.6           23.6
# 28  2021.10.6  100.0            48.7             53.1           18.8
# 29  2021.10.7  100.0            50.1             61.7           19.4
# 30  2021.10.8  100.0            39.3             47.1           18.8
# ⋮   ⋮          ⋮                ⋮                ⋮              ⋮
# 523 2023.9.1   100.0             29.0            41.1           24.5
# 524 2023.9.10  100.0             43.9            48.5           25.7
# 525 2023.9.11  100.0             42.1            47.3           25.5
# 526 2023.9.12  100.0             41.6            45.3           25.7
# 527 2023.9.13  100.0             42.8            46.4           22.1
# 528 2023.9.14  100.0             42.1            45.3           23.4
# 529 2023.9.15  100.0             38.7            47.6           22.3
# 530 2023.9.16  100.0             42.3            47.3           23.9
# 531 2023.9.17   77.3            100.0            35.3           24.7
# 532 2023.9.18  100.0             38.8            42.9           24.7
# 533 2023.9.19  100.0             39.7            45.0           24.1
# 541 18.6         20.8         27.8         95.8              0.0
# 542 20.0         23.7          4.4         90.1              0.1
# 543 19.6         27.3          0.0         78.3              8.4
# 544 17.4         26.9          0.0         61.5              5.5
# 545 23.1         28.8          0.1         77.8              1.9
# 546 17.1         22.2          4.5         77.0              1.6
# 547 24.3         30.2          0.3         79.9              0.7
# 548 25.0         32.8          0.0         69.5              7.0
# 549 24.0         32.1          0.0         65.1             11.3
# 550 20.9         31.6          0.0         54.8             12.1
# 551 19.6         30.5          0.0         60.3             12.0
# 552 20.8         31.2          0.0         66.3             10.9

# %% [markdown]
# # 예측모델구축

# %%
# 데이터의 컬럼 이름 확인
colnames(seoul_merge)

# 컬럼 이름 수정
names(seoul_merge)[1] <- "Date"
names(seoul_merge)[2] <- "MosquitoIndex_Water"
names(seoul_merge)[3] <- "MosquitoIndex_Residential"
names(seoul_merge)[4] <- "MosquitoIndex_Park"
names(seoul_merge)[5] <- "Temperature"
names(seoul_merge)[6] <- "MinTemperature"
names(seoul_merge)[7] <- "MaxTemperature"
names(seoul_merge)[8] <- "Precipitation"
names(seoul_merge)[9] <- "Humidity"
names(seoul_merge)[10] <- "Sunshine"

# 필요한 열만 선택
data <- seoul_merge %>%
  select(Temperature, Precipitation, Humidity, Sunshine, MosquitoIndex_Water, MosquitoIndex_Residential, MosquitoIndex_Park)

# 데이터 확인
head(data)
# Out:
#  [1] "일시"              "모기지수.수변부."  "모기지수.주거지."
#  [4] "모기지수.공원."    "평균기온..C."      "최저기온..C."
#  [7] "최고기온..C."      "일강수량.mm."      "평균.상대습도..."
# [10] "합계.일조시간.hr."
#   Temperature Precipitation Humidity Sunshine MosquitoIndex_Water
# 1 21.1        13.3          75.8     9.3      100.0
# 2 19.9        14.2          89.0     0.0      100.0
# 3 15.2         0.3          78.6     1.7      100.0
# 4 17.9         0.0          67.1     3.0       94.8
# 5 19.6         0.0          66.6     9.0       82.1
# 6 19.7         0.0          73.6     6.1       99.8
#   MosquitoIndex_Residential MosquitoIndex_Park
# 1 44.3                      47.6
# 2 41.2                      45.0
# 3 43.7                      50.1
# 4 40.1                      38.4
# 5 31.5                      27.9
# 6 36.7                      40.0

# %%
# train 데이터와 test 데이터로 나누기 (70% train, 30% test)
set.seed(123)  # 결과 재현을 위해 시드 설정
train_index <- createDataPartition(data$MosquitoIndex_Water, p = 0.7, list = FALSE)
train_data <- data[train_index, ]
test_data <- data[-train_index, ]

# GLM 모델 생성
glm_model <- glm(MosquitoIndex_Water ~ Temperature + Precipitation + Humidity + Sunshine, data = train_data, family = gaussian())

# %%
# 모델 성능 평가
predictions <- predict(glm_model, test_data)
actuals <- test_data$MosquitoIndex_Water

# RMSE 계산
rmse <- sqrt(mean((predictions - actuals)^2))
print(paste("RMSE: ", rmse))

# 모델 요약 정보
summary(glm_model)
# Out:
# [1] "RMSE:  13.3596237660246"
# Call:
# glm(formula = MosquitoIndex_Water ~ Temperature + Precipitation +
#     Humidity + Sunshine, family = gaussian(), data = train_data)
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   46.46204    7.27160   6.390 4.85e-10 ***
# Temperature    2.39938    0.14184  16.916  < 2e-16 ***
# Precipitation  0.02546    0.03801   0.670  0.50330
# Humidity      -0.06554    0.09008  -0.728  0.46728
# Sunshine      -0.73385    0.23759  -3.089  0.00216 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 170.1234)
#
#     Null deviance: 124236  on 386  degrees of freedom
# Residual deviance:  64987  on 382  degrees of freedom
# AIC: 3093.1
#
# Number of Fisher Scoring iterations: 2
